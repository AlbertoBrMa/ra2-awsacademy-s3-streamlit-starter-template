# %% [markdown]
# # Generar y subir datos IoT a S3
#
# Este notebook genera un JSON con datos IoT sintéticos y lo sube a S3 en `data/sensores/...`.

# %% [markdown]
# ## 1) Instalar dependencias
#
# Ejecuta esta celda para instalar automáticamente lo de `requirements.txt`.

# %%
from pathlib import Path

req = Path("requirements.txt")
if not req.exists():
    req = Path("../requirements.txt")
if not req.exists():
    raise FileNotFoundError("No se encontró requirements.txt")

# %pip install -r {req}
# Out:
# Requirement already satisfied: streamlit>=1.32 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.54.0)
# Requirement already satisfied: pandas>=2.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: boto3>=1.28 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (1.42.54)
# Requirement already satisfied: python-dotenv>=1.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: plotly>=5.20 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (6.5.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: packaging>=20 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from streamlit>=1.32->-r ../requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from pandas>=2.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from pandas>=2.0->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from pandas>=2.0->-r ../requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: jinja2 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.32->-r ../requirements.txt (line 1)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.32->-r ../requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.32->-r ../requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.32->-r ../requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.32->-r ../requirements.txt (line 1)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.32->-r ../requirements.txt (line 1)) (2026.1.4)
# Requirement already satisfied: botocore<1.43.0,>=1.42.54 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from boto3>=1.28->-r ../requirements.txt (line 3)) (1.42.54)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from boto3>=1.28->-r ../requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from boto3>=1.28->-r ../requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: six>=1.5 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/bertobm/miniconda3/envs/bigData/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.32->-r ../requirements.txt (line 1)) (0.30.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2) Configuración
#
# Rellena estos valores con tu bucket y región.

# %%
AWS_REGION = "us-east-1"
S3_BUCKET = "ra2-sbd-bertobm-20260221-8473"
S3_KEY = "data/sensores/iabd13_sensores.json"
ROWS = 200
SENSORS = 5

# %% [markdown]
# ## 3) Generar datos IoT

# %%
from datetime import datetime, timedelta, timezone
import json
import random
from pathlib import Path

def sensor_state_from_values(temperature_c: float, co2_ppm: float) -> str:
    if temperature_c >= 30 or co2_ppm >= 900:
        return "FAIL"
    if temperature_c >= 26 or co2_ppm >= 700:
        return "WARN"
    return "OK"

def generate_records(rows: int, sensors: int):
    base_time = datetime.now(timezone.utc) - timedelta(minutes=5 * rows)
    sensor_ids = [f"SEN-{i:03d}" for i in range(1, sensors + 1)]
    base_locations = [
        (40.4168, -3.7038),
        (41.3874, 2.1686),
        (39.4699, -0.3763),
        (37.3891, -5.9845),
        (43.2630, -2.9350),
    ]

    records = []
    for i in range(rows):
        sensor_id = random.choice(sensor_ids)
        lat0, lon0 = random.choice(base_locations)
        temperature_c = round(random.uniform(18.0, 33.0), 2)
        co2_ppm = round(random.uniform(420.0, 1100.0), 2)
        state = sensor_state_from_values(temperature_c, co2_ppm)

        records.append({
            "timestamp": (base_time + timedelta(minutes=5 * i)).isoformat(),
            "sensor_id": sensor_id,
            "sensor_state": state,
            "temperature_c": temperature_c,
            "co2_ppm": co2_ppm,
            "lat": round(lat0 + random.uniform(-0.02, 0.02), 6),
            "lon": round(lon0 + random.uniform(-0.02, 0.02), 6),
        })
    return records

records = generate_records(ROWS, SENSORS)
len(records), records[0]
# Out:
# (200,
#  {'timestamp': '2026-02-21T07:12:34.971512+00:00',
#   'sensor_id': 'SEN-004',
#   'sensor_state': 'WARN',
#   'temperature_c': 29.08,
#   'co2_ppm': 513.54,
#   'lat': 37.37651,
#   'lon': -5.98906})

# %% [markdown]
# ## 4) Guardar JSON local (opcional)

# %%
local_out = Path("./data/iabd13_sensores.json")
local_out.write_text(json.dumps(records, ensure_ascii=True, indent=2), encoding="utf-8")
local_out
# Out:
# PosixPath('data/iabd13_sensores.json')

# %% [markdown]
# ## 5) Subir a S3

# %%
import os
import boto3

for k in ["AWS_ACCESS_KEY_ID", "AWS_SECRET_ACCESS_KEY", "AWS_SESSION_TOKEN", "AWS_PROFILE", "AWS_DEFAULT_PROFILE"]:
    os.environ.pop(k, None)

session = boto3.Session(profile_name="awsacademy", region_name=AWS_REGION)
print(session.client("sts").get_caller_identity())

s3 = session.client("s3")
body = json.dumps(records, ensure_ascii=True, indent=2).encode("utf-8")
s3.put_object(Bucket=S3_BUCKET, Key=S3_KEY, Body=body, ContentType="application/json")
print(f"Subido a: s3://{S3_BUCKET}/{S3_KEY}")
# Out:
# {'UserId': 'AROAULJXNNU7ICVAJEMC7:user4587692=Alberto', 'Account': '299153321278', 'Arn': 'arn:aws:sts::299153321278:assumed-role/voclabs/user4587692=Alberto', 'ResponseMetadata': {'RequestId': '3bfca045-8336-4f02-8717-56243c351060', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '3bfca045-8336-4f02-8717-56243c351060', 'x-amz-sts-extended-request-id': 'MTp1cy1lYXN0LTE6UzoxNzcxNzE3OTU1NDQ5OlI6SExLQ000cnM=', 'content-type': 'text/xml', 'content-length': '452', 'date': 'Sat, 21 Feb 2026 23:52:35 GMT'}, 'RetryAttempts': 0}}
# Subido a: s3://ra2-sbd-bertobm-20260221-8473/data/sensores/iabd13_sensores.json
